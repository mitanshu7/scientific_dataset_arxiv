# %%
from glob import glob
import pandas as pd
from datasets import load_dataset
import os
from huggingface_hub import HfApi

# %%
## Verify trimmed parquet files
parquet_files = glob('arxiv_metadata_by_year/*.parquet')
parquet_files.sort()
parquet_files
# Out:
# ['arxiv_metadata_by_year\\arxiv_metadata_2007.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2008.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2009.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2010.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2011.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2012.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2013.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2014.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2015.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2016.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2017.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2018.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2019.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2020.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2021.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2022.parquet',
#  'arxiv_metadata_by_year\\arxiv_metadata_2023.parquet']

# %%
## write all the info to a text file
with open('arxiv_metadata_by_year/arxiv_metadata.txt', 'w') as f:
    for file in parquet_files:
        
        df = pd.read_parquet(file)

        f.write('#'*80 + '\n')
        f.write(f'{file} has {df.shape[0]} rows and {df.shape[1]} columns\n')
        f.write('Printing first 5 rows of the dataframe:\n')
        f.write(f'{df.head()}\n\n')
        f.write('Printing last 5 rows of the dataframe:\n')
        f.write(f'{df.tail()}\n\n')
        f.write('Printing random 5 rows of the dataframe:\n')
        f.write(f'{df.sample(5)}\n\n')
        f.write('Printing data types of the dataframe:\n')
        f.write(f'{df.dtypes}\n\n')
        f.write('Printing summary of the dataframe:\n')
        f.write(f'{df.describe()}\n\n')
        f.write('Printing missing values of the dataframe:\n')
        f.write(f'{df.isnull().sum()}\n\n')
        f.write('Printing unique values of the dataframe:\n')
        f.write(f'{df.nunique()}\n\n')
        f.write('Printing columns of the dataframe:\n')
        f.write(f'{df.columns}\n\n')
        f.write('Printing memory usage of the dataframe:\n')
        f.write(f'{df.info()}\n\n')
        f.write(f'{df.memory_usage()}\n\n')
        f.write(f'{df.memory_usage().sum()}\n\n')
        f.write(f'{df.memory_usage().sum() / 1024**2}\n\n')
        f.write('#'*80 + '\n')

# %%
## Setup the Hugging Face API
access_token =  os.environ.get("HUGGINGFACE_TOKEN")
api = HfApi(token=access_token)

## Verify the API
user = api.whoami()
user

# %%
folder_path = "arxiv_metadata_by_year"
repo_id = "bluuebunny/arxiv_metadata_by_year"  # Replace with your details
subfolder = "data"  # Optional subfolder within the repository

# Upload all files within the folder to the specified repository
api.upload_folder(repo_id=repo_id, folder_path=folder_path, path_in_repo=subfolder, repo_type="dataset")
# Out:
# arxiv_metadata_2007.parquet:   0%|          | 0.00/29.8M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2007.parquet:   0%|          | 16.4k/29.8M [00:00<15:43, 31.6kB/s]
#
#
#
# arxiv_metadata_2007.parquet:   2%|▏         | 639k/29.8M [00:00<00:21, 1.37MB/s]
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2007.parquet:   5%|▌         | 1.56M/29.8M [00:00<00:09, 3.12MB/s]
#
#
#
#
#
# arxiv_metadata_2007.parquet:   7%|▋         | 2.21M/29.8M [00:00<00:07, 3.70MB/s]
#
#
#
# arxiv_metadata_2007.parquet:  18%|█▊        | 5.37M/29.8M [00:01<00:02, 9.22MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2007.parquet:  22%|██▏       | 6.54M/29.8M [00:01<00:04, 5.06MB/s]
# arxiv_metadata_2007.parquet:  25%|██▍       | 7.41M/29.8M [00:01<00:04, 5.55MB/s]
#
#
# arxiv_metadata_2007.parquet:  28%|██▊       | 8.40M/29.8M [00:01<00:03, 6.38MB/s]
#
#
# arxiv_metadata_2007.parquet:  32%|███▏      | 9.50M/29.8M [00:01<00:02, 7.32MB/s]
#
#
#
#
#
#
# arxiv_metadata_2007.parquet:  36%|███▋      | 10.8M/29.8M [00:01<00:02, 8.62MB/s]
#
#
# arxiv_metadata_2007.parquet:  40%|████      | 12.0M/29.8M [00:02<00:01, 9.46MB/s]
#
#
# arxiv_metadata_2007.parquet:  45%|████▍     | 13.3M/29.8M [00:02<00:01, 9.77MB/s]
#
#
#
#
#
#
# arxiv_metadata_2007.parquet:  49%|████▉     | 14.6M/29.8M [00:02<00:01, 10.7MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2007.parquet:  54%|█████▍    | 16.0M/29.8M [00:02<00:02, 6.44MB/s]
#
#
#
#
# arxiv_metadata_2007.parquet:  58%|█████▊    | 17.2M/29.8M [00:02<00:01, 7.37MB/s]
#
#
#
#
# arxiv_metadata_2007.parquet:  62%|██████▏   | 18.4M/29.8M [00:02<00:01, 8.22MB/s]
#
#
#
#
# arxiv_metadata_2007.parquet:  66%|██████▌   | 19.6M/29.8M [00:02<00:01, 8.87MB/s]
#
#
#
#
# arxiv_metadata_2007.parquet:  69%|██████▉   | 20.6M/29.8M [00:03<00:01, 9.08MB/s]
#
#
#
#
# arxiv_metadata_2007.parquet:  74%|███████▎  | 21.9M/29.8M [00:03<00:00, 9.76MB/s]
#
#
#
#
# arxiv_metadata_2007.parquet:  77%|███████▋  | 23.0M/29.8M [00:03<00:00, 9.91MB/s]
#
#
#
#
#
#
# arxiv_metadata_2007.parquet:  81%|████████  | 24.1M/29.8M [00:03<00:00, 9.82MB/s]
#
#
# arxiv_metadata_2007.parquet:  85%|████████▍ | 25.2M/29.8M [00:03<00:00, 10.2MB/s]
#
#
# arxiv_metadata_2007.parquet:  88%|████████▊ | 26.3M/29.8M [00:03<00:00, 10.2MB/s]
#
#
# arxiv_metadata_2007.parquet:  92%|█████████▏| 27.5M/29.8M [00:03<00:00, 10.3MB/s]
#
#
#
#
#
# arxiv_metadata_2007.parquet:  96%|█████████▌| 28.6M/29.8M [00:03<00:00, 10.4MB/s]
#
#
#
#
#
#
# arxiv_metadata_2007.parquet: 100%|█████████▉| 29.7M/29.8M [00:03<00:00, 10.2MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2007.parquet: 100%|██████████| 29.8M/29.8M [00:04<00:00, 6.51MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:   0%|          | 0.00/66.3M [00:00<?, ?B/s]
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:   3%|▎         | 1.69M/66.3M [00:00<00:03, 16.7MB/s]
#
# arxiv_metadata_2012.parquet:   5%|▌         | 3.38M/66.3M [00:00<00:04, 13.5MB/s]
#
#
# arxiv_metadata_2012.parquet:   7%|▋         | 4.77M/66.3M [00:00<00:04, 13.0MB/s]
#
# arxiv_metadata_2012.parquet:   9%|▉         | 6.09M/66.3M [00:00<00:04, 13.0MB/s]
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  12%|█▏        | 7.70M/66.3M [00:00<00:04, 13.9MB/s]
#
#
# arxiv_metadata_2012.parquet:  14%|█▍        | 9.29M/66.3M [00:00<00:04, 14.2MB/s]
#
#
#
#
#
# arxiv_metadata_2012.parquet:  16%|█▌        | 10.7M/66.3M [00:00<00:04, 13.1MB/s]
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  18%|█▊        | 12.1M/66.3M [00:00<00:04, 11.4MB/s]
#
#
#
#
#
# arxiv_metadata_2012.parquet:  20%|██        | 13.3M/66.3M [00:01<00:05, 10.6MB/s]
#
#
#
#
#
#
#
# arxiv_metadata_2009.parquet: 100%|██████████| 46.9M/46.9M [00:06<00:00, 7.08MB/s]
# arxiv_metadata_2012.parquet:  23%|██▎       | 15.3M/66.3M [00:01<00:05, 8.65MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  24%|██▍       | 16.2M/66.3M [00:02<00:14, 3.47MB/s]
#
#
#
# arxiv_metadata_2012.parquet:  27%|██▋       | 18.0M/66.3M [00:02<00:09, 5.13MB/s]
#
#
#
# arxiv_metadata_2012.parquet:  30%|███       | 20.0M/66.3M [00:02<00:06, 7.32MB/s]
# arxiv_metadata_2012.parquet:  34%|███▎      | 22.3M/66.3M [00:02<00:04, 9.87MB/s]
# arxiv_metadata_2012.parquet:  36%|███▋      | 24.1M/66.3M [00:02<00:03, 11.5MB/s]
# arxiv_metadata_2008.parquet: 100%|██████████| 42.3M/42.3M [00:07<00:00, 5.29MB/s]
#
# arxiv_metadata_2012.parquet:  42%|████▏     | 28.0M/66.3M [00:02<00:02, 14.4MB/s]
# arxiv_metadata_2012.parquet:  45%|████▍     | 29.8M/66.3M [00:02<00:02, 15.3MB/s]
# arxiv_metadata_2012.parquet:  48%|████▊     | 31.9M/66.3M [00:02<00:02, 16.6MB/s]
#
# arxiv_metadata_2012.parquet:  66%|██████▌   | 43.5M/66.3M [00:03<00:01, 21.3MB/s]
# arxiv_metadata_2012.parquet:  69%|██████▉   | 46.0M/66.3M [00:03<00:01, 20.2MB/s]
#
#
# arxiv_metadata_2010.parquet: 100%|██████████| 52.9M/52.9M [00:09<00:00, 5.57MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2011.parquet: 100%|██████████| 58.8M/58.8M [00:10<00:00, 5.52MB/s]
# arxiv_metadata_2012.parquet:  73%|███████▎  | 48.4M/66.3M [00:05<00:03, 4.54MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  75%|███████▌  | 50.1M/66.3M [00:05<00:03, 4.15MB/s]
#
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  78%|███████▊  | 52.0M/66.3M [00:05<00:02, 5.24MB/s]
#
#
#
# arxiv_metadata_2012.parquet:  81%|████████  | 53.5M/66.3M [00:06<00:02, 6.02MB/s]
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  83%|████████▎ | 54.9M/66.3M [00:06<00:01, 6.45MB/s]
#
#
#
#
# arxiv_metadata_2012.parquet:  85%|████████▍ | 56.1M/66.3M [00:06<00:01, 6.73MB/s]
#
#
#
#
# arxiv_metadata_2012.parquet:  86%|████████▋ | 57.3M/66.3M [00:06<00:01, 6.94MB/s]
#
#
#
#
#
# arxiv_metadata_2012.parquet:  88%|████████▊ | 58.3M/66.3M [00:06<00:01, 7.15MB/s]
#
#
#
#
# arxiv_metadata_2012.parquet:  89%|████████▉ | 59.2M/66.3M [00:06<00:00, 7.50MB/s]
#
#
#
# arxiv_metadata_2012.parquet:  91%|█████████ | 60.2M/66.3M [00:06<00:00, 7.88MB/s]
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  92%|█████████▏| 61.2M/66.3M [00:06<00:00, 8.44MB/s]
#
# arxiv_metadata_2012.parquet:  94%|█████████▍| 62.3M/66.3M [00:07<00:00, 8.98MB/s]
# arxiv_metadata_2012.parquet:  96%|█████████▌| 63.5M/66.3M [00:07<00:00, 9.75MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet:  97%|█████████▋| 64.6M/66.3M [00:07<00:00, 5.96MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2012.parquet: 100%|██████████| 66.3M/66.3M [00:09<00:00, 7.32MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:   0%|          | 0.00/105M [00:00<?, ?B/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:   1%|▏         | 1.33M/105M [00:00<00:08, 12.0MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:   2%|▏         | 2.54M/105M [00:00<00:09, 10.9MB/s]
#
#
#
# arxiv_metadata_2017.parquet:   3%|▎         | 3.64M/105M [00:00<00:09, 10.6MB/s]
#
#
# arxiv_metadata_2017.parquet:   5%|▍         | 4.75M/105M [00:00<00:09, 10.6MB/s]
# arxiv_metadata_2017.parquet:   6%|▌         | 5.93M/105M [00:00<00:09, 11.0MB/s]
# arxiv_metadata_2017.parquet:   7%|▋         | 7.36M/105M [00:00<00:08, 11.5MB/s]
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:   8%|▊         | 8.75M/105M [00:00<00:07, 12.0MB/s]
# arxiv_metadata_2017.parquet:  10%|▉         | 9.96M/105M [00:00<00:07, 11.9MB/s]
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  11%|█         | 11.4M/105M [00:00<00:07, 11.8MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  12%|█▏        | 12.6M/105M [00:01<00:07, 11.7MB/s]
#
# arxiv_metadata_2017.parquet:  13%|█▎        | 13.9M/105M [00:01<00:07, 12.3MB/s]
#
#
#
#
#
# arxiv_metadata_2017.parquet:  15%|█▍        | 15.7M/105M [00:01<00:06, 13.7MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  16%|█▋        | 17.1M/105M [00:01<00:11, 7.59MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  17%|█▋        | 18.2M/105M [00:01<00:10, 8.08MB/s]
#
#
# arxiv_metadata_2017.parquet:  18%|█▊        | 19.3M/105M [00:01<00:10, 8.27MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  19%|█▉        | 20.3M/105M [00:02<00:10, 8.34MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  20%|██        | 21.3M/105M [00:02<00:09, 8.73MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  21%|██▏       | 22.3M/105M [00:02<00:09, 8.80MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  22%|██▏       | 23.3M/105M [00:02<00:09, 8.81MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  23%|██▎       | 24.2M/105M [00:02<00:09, 8.11MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  24%|██▍       | 25.0M/105M [00:02<00:09, 8.00MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  25%|██▍       | 25.9M/105M [00:02<00:09, 7.95MB/s]
#
#
# arxiv_metadata_2017.parquet:  26%|██▌       | 27.1M/105M [00:02<00:08, 8.96MB/s]
#
#
# arxiv_metadata_2017.parquet:  27%|██▋       | 28.2M/105M [00:02<00:07, 9.61MB/s]
#
# arxiv_metadata_2014.parquet: 100%|██████████| 79.2M/79.2M [00:08<00:00, 9.18MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  28%|██▊       | 29.7M/105M [00:03<00:07, 10.7MB/s]
#
#
#
#
#
# arxiv_metadata_2017.parquet:  30%|██▉       | 31.0M/105M [00:03<00:06, 11.0MB/s]
#
#
#
#
#
#
#
# arxiv_metadata_2013.parquet: 100%|██████████| 73.4M/73.4M [00:10<00:00, 7.01MB/s]
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  32%|███▏      | 33.0M/105M [00:03<00:10, 6.57MB/s]
#
#
#
#
#
# arxiv_metadata_2017.parquet:  32%|███▏      | 33.9M/105M [00:03<00:10, 6.92MB/s]
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  33%|███▎      | 34.8M/105M [00:03<00:09, 7.24MB/s]
#
#
# arxiv_metadata_2017.parquet:  34%|███▍      | 35.6M/105M [00:03<00:09, 6.92MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  35%|███▍      | 36.4M/105M [00:04<00:10, 6.21MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  35%|███▌      | 37.1M/105M [00:04<00:10, 6.18MB/s]
#
#
# arxiv_metadata_2017.parquet:  36%|███▌      | 37.8M/105M [00:04<00:10, 6.30MB/s]
#
#
# arxiv_metadata_2017.parquet:  37%|███▋      | 38.5M/105M [00:04<00:10, 6.52MB/s]
#
#
# arxiv_metadata_2017.parquet:  38%|███▊      | 39.3M/105M [00:04<00:09, 6.75MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  38%|███▊      | 40.1M/105M [00:04<00:08, 7.23MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  39%|███▉      | 41.2M/105M [00:04<00:07, 8.05MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  40%|████      | 42.2M/105M [00:04<00:07, 8.73MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  41%|████      | 43.1M/105M [00:04<00:07, 8.28MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  42%|████▏     | 44.0M/105M [00:05<00:07, 8.10MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  43%|████▎     | 44.8M/105M [00:05<00:08, 7.44MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  44%|████▎     | 45.6M/105M [00:05<00:08, 6.91MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  44%|████▍     | 46.3M/105M [00:05<00:08, 6.67MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  45%|████▍     | 47.1M/105M [00:05<00:08, 7.02MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  46%|████▌     | 47.8M/105M [00:05<00:08, 6.95MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  46%|████▋     | 48.5M/105M [00:06<00:14, 3.96MB/s]
#
#
#
# arxiv_metadata_2017.parquet:  47%|████▋     | 49.4M/105M [00:06<00:11, 4.66MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  48%|████▊     | 50.7M/105M [00:06<00:08, 6.08MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  49%|████▉     | 51.7M/105M [00:06<00:07, 6.93MB/s]
#
#
# arxiv_metadata_2017.parquet:  51%|█████     | 52.9M/105M [00:06<00:06, 8.03MB/s]
#
#
# arxiv_metadata_2017.parquet:  51%|█████▏    | 53.9M/105M [00:06<00:06, 8.31MB/s]
#
#
# arxiv_metadata_2017.parquet:  52%|█████▏    | 54.8M/105M [00:06<00:05, 8.65MB/s]
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  53%|█████▎    | 55.8M/105M [00:06<00:06, 7.87MB/s]
#
#
# arxiv_metadata_2017.parquet:  54%|█████▍    | 56.6M/105M [00:06<00:06, 7.68MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  55%|█████▍    | 57.5M/105M [00:07<00:06, 7.80MB/s]
#
#
#
# arxiv_metadata_2017.parquet:  56%|█████▌    | 58.3M/105M [00:07<00:06, 7.44MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  57%|█████▋    | 59.2M/105M [00:07<00:05, 7.69MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  57%|█████▋    | 60.1M/105M [00:07<00:05, 7.83MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  58%|█████▊    | 60.9M/105M [00:07<00:05, 8.00MB/s]
#
#
#
#
# arxiv_metadata_2015.parquet: 100%|██████████| 86.2M/86.2M [00:12<00:00, 7.08MB/s]
# arxiv_metadata_2017.parquet:  59%|█████▉    | 61.7M/105M [00:07<00:05, 7.99MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  60%|█████▉    | 62.8M/105M [00:07<00:04, 8.54MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  61%|██████    | 63.6M/105M [00:07<00:04, 8.52MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  62%|██████▏   | 64.5M/105M [00:08<00:08, 4.85MB/s]
#
#
# arxiv_metadata_2017.parquet:  63%|██████▎   | 65.7M/105M [00:08<00:06, 6.17MB/s]
#
# arxiv_metadata_2017.parquet:  64%|██████▍   | 67.2M/105M [00:08<00:04, 8.18MB/s]
#
# arxiv_metadata_2016.parquet: 100%|██████████| 94.8M/94.8M [00:11<00:00, 7.90MB/s]
#
#
#
# arxiv_metadata_2017.parquet:  67%|██████▋   | 70.5M/105M [00:08<00:03, 11.1MB/s]
#
#
# arxiv_metadata_2017.parquet:  69%|██████▊   | 71.7M/105M [00:08<00:02, 11.2MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  70%|██████▉   | 73.0M/105M [00:08<00:03, 10.0MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  71%|███████   | 74.1M/105M [00:09<00:03, 8.54MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  72%|███████▏  | 75.0M/105M [00:09<00:03, 7.82MB/s]
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  72%|███████▏  | 75.9M/105M [00:09<00:04, 7.09MB/s]
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  73%|███████▎  | 76.6M/105M [00:09<00:04, 6.52MB/s]
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  74%|███████▍  | 77.3M/105M [00:09<00:04, 6.18MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  74%|███████▍  | 78.0M/105M [00:09<00:04, 6.09MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  75%|███████▌  | 78.7M/105M [00:09<00:04, 6.35MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  76%|███████▌  | 79.4M/105M [00:09<00:04, 6.21MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  76%|███████▋  | 80.0M/105M [00:10<00:07, 3.28MB/s]
#
# arxiv_metadata_2017.parquet:  78%|███████▊  | 81.5M/105M [00:10<00:04, 5.06MB/s]
#
# arxiv_metadata_2017.parquet:  79%|███████▉  | 82.5M/105M [00:10<00:03, 6.00MB/s]
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  80%|███████▉  | 83.4M/105M [00:10<00:03, 6.00MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  80%|████████  | 84.1M/105M [00:10<00:03, 6.13MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  81%|████████  | 84.9M/105M [00:11<00:03, 6.09MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  82%|████████▏ | 85.6M/105M [00:11<00:03, 5.66MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  82%|████████▏ | 86.2M/105M [00:11<00:03, 5.54MB/s]
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  83%|████████▎ | 86.8M/105M [00:11<00:03, 5.48MB/s]
#
#
#
# arxiv_metadata_2017.parquet:  83%|████████▎ | 87.4M/105M [00:11<00:03, 5.40MB/s]
#
#
#
#
#
# arxiv_metadata_2017.parquet:  84%|████████▍ | 88.1M/105M [00:11<00:02, 5.68MB/s]
#
#
#
# arxiv_metadata_2017.parquet:  85%|████████▍ | 88.8M/105M [00:11<00:02, 6.17MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  86%|████████▌ | 89.5M/105M [00:11<00:02, 6.35MB/s]
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  86%|████████▌ | 90.2M/105M [00:11<00:02, 6.12MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  87%|████████▋ | 90.8M/105M [00:12<00:02, 5.61MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  87%|████████▋ | 91.5M/105M [00:12<00:02, 5.88MB/s]
#
#
# arxiv_metadata_2017.parquet:  88%|████████▊ | 92.1M/105M [00:12<00:02, 5.62MB/s]
#
#
# arxiv_metadata_2017.parquet:  89%|████████▊ | 92.8M/105M [00:12<00:01, 5.92MB/s]
#
#
# arxiv_metadata_2017.parquet:  90%|████████▉ | 94.0M/105M [00:12<00:01, 7.09MB/s]
#
#
#
# arxiv_metadata_2017.parquet:  91%|█████████ | 94.9M/105M [00:12<00:01, 7.53MB/s]
#
# arxiv_metadata_2017.parquet:  92%|█████████▏| 95.8M/105M [00:12<00:01, 7.88MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  92%|█████████▏| 96.6M/105M [00:13<00:01, 4.21MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  93%|█████████▎| 97.4M/105M [00:13<00:01, 4.97MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  94%|█████████▍| 98.2M/105M [00:13<00:01, 5.44MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  95%|█████████▍| 99.0M/105M [00:13<00:00, 6.00MB/s]
#
#
#
#
# arxiv_metadata_2017.parquet:  96%|█████████▌| 100M/105M [00:13<00:00, 6.73MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  96%|█████████▋| 101M/105M [00:13<00:00, 6.64MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  97%|█████████▋| 101M/105M [00:13<00:00, 6.71MB/s]
#
#
#
#
#
# arxiv_metadata_2017.parquet:  98%|█████████▊| 102M/105M [00:13<00:00, 6.68MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  98%|█████████▊| 103M/105M [00:14<00:00, 6.74MB/s]
#
#
#
#
#
#
# arxiv_metadata_2017.parquet:  99%|█████████▉| 104M/105M [00:14<00:00, 6.44MB/s]
#
#
#
# arxiv_metadata_2017.parquet: 100%|█████████▉| 104M/105M [00:14<00:00, 6.29MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2017.parquet: 100%|██████████| 105M/105M [00:14<00:00, 7.14MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   0%|          | 0.00/170M [00:00<?, ?B/s]
#
#
#
#
# arxiv_metadata_2022.parquet:   1%|          | 885k/170M [00:00<00:20, 8.47MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   1%|          | 1.77M/170M [00:00<00:21, 8.01MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:   2%|▏         | 2.61M/170M [00:00<00:20, 8.12MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:   2%|▏         | 3.47M/170M [00:00<00:20, 8.32MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:   3%|▎         | 4.34M/170M [00:00<00:19, 8.35MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:   4%|▎         | 6.11M/170M [00:00<00:20, 7.86MB/s]
#
#
# arxiv_metadata_2022.parquet:   4%|▍         | 7.13M/170M [00:00<00:19, 8.31MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   5%|▌         | 8.62M/170M [00:00<00:16, 10.1MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   6%|▌         | 9.65M/170M [00:01<00:17, 8.97MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   6%|▌         | 10.6M/170M [00:01<00:18, 8.60MB/s]
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   7%|▋         | 11.5M/170M [00:01<00:21, 7.47MB/s]
#
#
#
# arxiv_metadata_2022.parquet:   7%|▋         | 12.3M/170M [00:01<00:21, 7.46MB/s]
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   8%|▊         | 13.1M/170M [00:01<00:22, 7.00MB/s]
#
#
#
# arxiv_metadata_2022.parquet:   8%|▊         | 13.9M/170M [00:01<00:22, 7.05MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:   9%|▊         | 14.6M/170M [00:01<00:22, 7.02MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:   9%|▉         | 15.5M/170M [00:01<00:20, 7.44MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  10%|▉         | 16.2M/170M [00:02<00:41, 3.69MB/s]
# arxiv_metadata_2022.parquet:  10%|█         | 17.6M/170M [00:02<00:29, 5.14MB/s]
# arxiv_metadata_2022.parquet:  11%|█▏        | 19.2M/170M [00:02<00:21, 7.06MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  12%|█▏        | 20.4M/170M [00:02<00:19, 7.85MB/s]
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  13%|█▎        | 21.4M/170M [00:02<00:20, 7.17MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  13%|█▎        | 22.3M/170M [00:03<00:21, 6.96MB/s]
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  14%|█▎        | 23.1M/170M [00:03<00:21, 6.91MB/s]
#
#
# arxiv_metadata_2022.parquet:  14%|█▍        | 23.9M/170M [00:03<00:21, 6.86MB/s]
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  14%|█▍        | 24.6M/170M [00:03<00:22, 6.53MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  15%|█▍        | 25.5M/170M [00:03<00:20, 6.91MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  15%|█▌        | 26.3M/170M [00:03<00:20, 7.13MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  16%|█▌        | 27.1M/170M [00:03<00:19, 7.27MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  16%|█▋        | 27.8M/170M [00:03<00:20, 6.88MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  17%|█▋        | 28.8M/170M [00:04<00:19, 7.29MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  17%|█▋        | 29.8M/170M [00:04<00:17, 7.96MB/s]
#
# arxiv_metadata_2022.parquet:  18%|█▊        | 30.6M/170M [00:04<00:17, 7.97MB/s]
#
#
# arxiv_metadata_2022.parquet:  19%|█▉        | 32.0M/170M [00:04<00:14, 9.50MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  19%|█▉        | 33.0M/170M [00:04<00:27, 5.08MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  20%|█▉        | 33.7M/170M [00:04<00:25, 5.35MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  20%|██        | 34.4M/170M [00:04<00:23, 5.71MB/s]
#
#
# arxiv_metadata_2022.parquet:  21%|██        | 35.3M/170M [00:05<00:22, 5.90MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  21%|██        | 36.0M/170M [00:05<00:21, 6.15MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  22%|██▏       | 36.7M/170M [00:05<00:21, 6.32MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  22%|██▏       | 37.5M/170M [00:05<00:20, 6.47MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  22%|██▏       | 38.2M/170M [00:05<00:20, 6.41MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  23%|██▎       | 38.9M/170M [00:05<00:21, 5.99MB/s]
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  23%|██▎       | 39.8M/170M [00:05<00:18, 6.91MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  24%|██▍       | 40.6M/170M [00:05<00:18, 6.89MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  24%|██▍       | 41.3M/170M [00:05<00:19, 6.59MB/s]
#
#
# arxiv_metadata_2022.parquet:  25%|██▍       | 42.1M/170M [00:06<00:18, 7.07MB/s]
#
# arxiv_metadata_2022.parquet:  26%|██▌       | 43.6M/170M [00:06<00:14, 8.81MB/s]
#
# arxiv_metadata_2022.parquet:  26%|██▋       | 45.1M/170M [00:06<00:12, 10.4MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  27%|██▋       | 46.2M/170M [00:06<00:12, 9.84MB/s]
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  28%|██▊       | 47.2M/170M [00:06<00:14, 8.65MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  28%|██▊       | 48.0M/170M [00:07<00:29, 4.16MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  29%|██▉       | 49.1M/170M [00:07<00:26, 4.65MB/s]
#
#
#
# arxiv_metadata_2022.parquet:  29%|██▉       | 49.8M/170M [00:07<00:24, 4.90MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  30%|██▉       | 50.5M/170M [00:07<00:23, 5.20MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  31%|███       | 52.1M/170M [00:07<00:16, 7.22MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  31%|███       | 53.1M/170M [00:07<00:15, 7.75MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  32%|███▏      | 54.7M/170M [00:07<00:12, 9.53MB/s]
#
#
#
# arxiv_metadata_2019.parquet: 100%|██████████| 137M/137M [00:19<00:00, 7.13MB/s]
#
#
# arxiv_metadata_2022.parquet:  33%|███▎      | 55.9M/170M [00:07<00:11, 9.76MB/s]
#
# arxiv_metadata_2022.parquet:  34%|███▍      | 57.8M/170M [00:08<00:09, 12.0MB/s]
#
# arxiv_metadata_2022.parquet:  35%|███▌      | 60.0M/170M [00:08<00:07, 14.5MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  36%|███▌      | 61.6M/170M [00:08<00:07, 14.1MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  37%|███▋      | 63.1M/170M [00:08<00:07, 14.3MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  38%|███▊      | 64.6M/170M [00:08<00:14, 7.54MB/s]
#
#
# arxiv_metadata_2018.parquet: 100%|██████████| 121M/121M [00:20<00:00, 5.86MB/s]]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  39%|███▉      | 67.0M/170M [00:09<00:12, 8.61MB/s]
# arxiv_metadata_2022.parquet:  40%|████      | 68.3M/170M [00:09<00:11, 9.20MB/s]
# arxiv_metadata_2022.parquet:  41%|████      | 69.8M/170M [00:09<00:09, 10.3MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  42%|████▏     | 71.0M/170M [00:09<00:10, 9.44MB/s]
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  43%|████▎     | 73.0M/170M [00:09<00:08, 11.0MB/s]
#
#
# arxiv_metadata_2022.parquet:  44%|████▎     | 74.5M/170M [00:09<00:08, 11.8MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  44%|████▍     | 75.8M/170M [00:09<00:08, 11.4MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  45%|████▌     | 77.0M/170M [00:09<00:08, 11.1MB/s]
#
# arxiv_metadata_2022.parquet:  46%|████▌     | 78.4M/170M [00:09<00:07, 11.7MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  47%|████▋     | 80.0M/170M [00:10<00:13, 6.81MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  48%|████▊     | 82.0M/170M [00:10<00:10, 8.54MB/s]
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  49%|████▉     | 83.1M/170M [00:10<00:09, 8.78MB/s]
#
#
#
# arxiv_metadata_2022.parquet:  49%|████▉     | 84.2M/170M [00:10<00:09, 9.04MB/s]
#
#
# arxiv_metadata_2022.parquet:  50%|█████     | 85.3M/170M [00:10<00:09, 9.35MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  51%|█████     | 86.3M/170M [00:11<00:08, 9.40MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  51%|█████     | 87.4M/170M [00:11<00:08, 9.40MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  52%|█████▏    | 88.4M/170M [00:11<00:08, 9.48MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  53%|█████▎    | 91.0M/170M [00:11<00:05, 13.9MB/s]
#
#
#
#
#
# arxiv_metadata_2022.parquet:  55%|█████▍    | 93.4M/170M [00:11<00:04, 16.0MB/s]
#
#
#
# arxiv_metadata_2022.parquet:  56%|█████▌    | 95.0M/170M [00:11<00:05, 14.7MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  57%|█████▋    | 96.6M/170M [00:12<00:18, 3.92MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  58%|█████▊    | 98.2M/170M [00:12<00:14, 5.03MB/s]
# arxiv_metadata_2022.parquet:  58%|█████▊    | 99.5M/170M [00:12<00:12, 5.77MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  59%|█████▉    | 101M/170M [00:13<00:10, 6.48MB/s]
#
#
# arxiv_metadata_2022.parquet:  60%|█████▉    | 102M/170M [00:13<00:09, 7.09MB/s]
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  60%|██████    | 103M/170M [00:13<00:08, 7.73MB/s]
#
# arxiv_metadata_2022.parquet:  61%|██████    | 104M/170M [00:13<00:08, 8.18MB/s]
#
# arxiv_metadata_2022.parquet:  62%|██████▏   | 105M/170M [00:13<00:07, 8.53MB/s]
#
# arxiv_metadata_2022.parquet:  65%|██████▍   | 110M/170M [00:13<00:04, 14.8MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2022.parquet:  66%|██████▌   | 112M/170M [00:14<00:07, 8.30MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  67%|██████▋   | 115M/170M [00:14<00:05, 10.8MB/s]
#
#
#
#
# arxiv_metadata_2020.parquet: 100%|██████████| 161M/161M [00:21<00:00, 7.45MB/s]
#
#
#
#
# arxiv_metadata_2022.parquet:  70%|██████▉   | 119M/170M [00:14<00:04, 12.8MB/s]
#
#
#
# arxiv_metadata_2022.parquet:  71%|███████   | 120M/170M [00:14<00:03, 13.1MB/s]
#
#
#
# arxiv_metadata_2022.parquet:  74%|███████▎  | 126M/170M [00:14<00:02, 18.4MB/s]
#
#
#
#
#
# arxiv_metadata_2021.parquet: 100%|██████████| 166M/166M [00:21<00:00, 7.78MB/s]
#
#
# arxiv_metadata_2022.parquet:  77%|███████▋  | 131M/170M [00:15<00:02, 13.3MB/s]
#
#
# arxiv_metadata_2022.parquet:  82%|████████▏ | 140M/170M [00:15<00:01, 21.6MB/s]
# arxiv_metadata_2022.parquet:  84%|████████▎ | 143M/170M [00:15<00:01, 22.6MB/s]
#
#
#
# arxiv_metadata_2022.parquet:  92%|█████████▏| 156M/170M [00:16<00:00, 22.0MB/s]
# arxiv_metadata_2022.parquet:  94%|█████████▎| 160M/170M [00:16<00:00, 23.5MB/s]
#
#
# arxiv_metadata_2022.parquet:  95%|█████████▌| 163M/170M [00:17<00:00, 15.0MB/s]
# arxiv_metadata_2022.parquet: 100%|█████████▉| 170M/170M [00:17<00:00, 19.4MB/s]
# arxiv_metadata_2022.parquet: 100%|██████████| 170M/170M [00:17<00:00, 9.51MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arxiv_metadata_2023.parquet: 100%|██████████| 193M/193M [00:12<00:00, 15.4MB/s]
#
#
#
# Upload 17 LFS files: 100%|██████████| 17/17 [00:51<00:00,  3.05s/it]
# CommitInfo(commit_url='https://huggingface.co/datasets/bluuebunny/arxiv_metadata_by_year/commit/11e29059fad6cde300c3c1de74234e2e42df84e4', commit_message='Upload folder using huggingface_hub', commit_description='', oid='11e29059fad6cde300c3c1de74234e2e42df84e4', pr_url=None, pr_revision=None, pr_num=None)
